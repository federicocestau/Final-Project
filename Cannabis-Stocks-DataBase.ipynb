# %%
import pandas as pd

# %%
df1 = pd.read_csv ('C:/Users/User/Project 3/ACAN.csv')

# %%
df1['Ticker'] = 'ACAN'

# %%
df1
# Out:
#          Date   Open   High    Low  Close  Adj Close   Volume Ticker
# 0    7/1/2017  2.600  2.650  1.560  2.558      2.558   689500   ACAN
# 1    8/1/2017  1.600  2.230  1.110  1.726      1.726  1767000   ACAN
# 2    9/1/2017  1.730  2.430  1.250  1.900      1.900  1172800   ACAN
# 3   10/1/2017  1.925  2.050  1.700  1.770      1.770   513500   ACAN
# 4   11/1/2017  1.770  2.470  1.560  2.030      2.030  1047400   ACAN
# 5   12/1/2017  2.020  4.900  2.020  4.090      4.090  2316900   ACAN
# 6    1/1/2018  4.425  5.350  2.560  3.300      3.300  3900200   ACAN
# 7    2/1/2018  3.300  3.490  2.610  2.710      2.710   861900   ACAN
# 8    3/1/2018  2.780  2.780  1.900  1.940      1.940   613700   ACAN
# 9    4/1/2018  1.980  3.766  1.700  3.640      3.640  1193000   ACAN
# 10   5/1/2018  3.680  4.700  2.680  3.750      3.750  2906400   ACAN
# 11   6/1/2018  3.850  3.970  3.050  3.449      3.449  1946000   ACAN
# 12   7/1/2018  3.300  3.450  2.120  2.410      2.410  1176500   ACAN
# ...

# %%
df2 = pd.read_csv ('C:/Users/User/Project 3/ACB.csv')

# %%
df3 = pd.read_csv ('C:/Users/User/Project 3/AMRS.csv')

# %%
df4 = pd.read_csv ('C:/Users/User/Project 3/APHA.csv')

# %%
df5 = pd.read_csv ('C:/Users/User/Project 3/CARA.csv')

# %%
df6 = pd.read_csv ('C:/Users/User/Project 3/CRBP.csv')

# %%
df7 = pd.read_csv ('C:/Users/User/Project 3/GTBIF.csv')

# %%
df8 = pd.read_csv ('C:/Users/User/Project 3/IIPR.csv')

# %%
df9 = pd.read_csv ('C:/Users/User/Project 3/MJ.csv')

# %%
df10 = pd.read_csv ('C:/Users/User/Project 3/MRMD.csv')

# %%
df11 = pd.read_csv ('C:/Users/User/Project 3/NBEV.csv')

# %%
df12 = pd.read_csv ('C:/Users/User/Project 3/TGOD.csv')

# %%
df13 = pd.read_csv ('C:/Users/User/Project 3/TGODF.csv')

# %%
df14 = pd.read_csv ('C:/Users/User/Project 3/TLRY.csv')

# %%
df15 = pd.read_csv ('C:/Users/User/Project 3/TRST.csv')

# %%
df16 = pd.read_csv ('C:/Users/User/Project 3/TRTC.csv')

# %%
#Since November2018
df17 = pd.read_csv ('C:/Users/User/Project 3/ACRGF.csv')

# %%
#Since March 2018
df18 = pd.read_csv ('C:/Users/User/Project 3/ALEAF.csv')

# %%
#Since October 2018
df19 = pd.read_csv ('C:/Users/User/Project 3/CURLF.csv')

# %%
#Since November 2018
df20 = pd.read_csv ('C:/Users/User/Project 3/YCBD.csv')

# %%
df21 = pd.read_csv ('C:/Users/User/Project 3/CRON.csv')

# %%
df22 = pd.read_csv ('C:/Users/User/Project 3/GWPH.csv')

# %%
df23 = pd.read_csv ('C:/Users/User/Project 3/CGC.csv')

# %%
df24 = pd.read_csv ('C:/Users/User/Project 3/SMG.csv')

# %%
df25 = pd.read_csv ('C:/Users/User/Project 3/TAP.csv')

# %%
df26 = pd.read_csv ('C:/Users/User/Project 3/WEED.TO.csv')

# %%
#Since May2018
df27 = pd.read_csv ('C:/Users/User/Project 3/MMNFF.csv')

# %%
df28 = pd.read_csv ('C:/Users/User/Project 3/MO.csv')

# %%
df29 = pd.read_csv ('C:/Users/User/Project 3/BUD.csv')

# %%
#Since November 2018
df30 = pd.read_csv ('C:/Users/User/Project 3/HRVSF.csv')

# %%
#Since May 2018
df31 = pd.read_csv ('C:/Users/User/Project 3/TLLTF.csv')

# %%
#Since Nov 2018
df32 = pd.read_csv ('C:/Users/User/Project 3/AYRSF.csv')

# %%
#Since March 2018
df33 = pd.read_csv ('C:/Users/User/Project 3/GRWG.csv')

# %%
df34 = pd.read_csv ('C:/Users/User/Project 3/PLNHF.csv')

# %%
df35 = pd.read_csv ('C:/Users/User/Project 3/CXXIF.csv')

# %%
#Since march 2018
df36 = pd.read_csv ('C:/Users/User/Project 3/KSHB.csv')

# %%
df1['Ticker'] = 'ACAN'
df2['Ticker'] = 'ACB'
df3['Ticker'] = 'AMRS'
df4['Ticker'] = 'APHA'
df5['Ticker'] = 'CARA'
df6['Ticker'] = 'CRBP'
df7['Ticker'] = 'GTBIF'
df8['Ticker'] = 'IIPR'
df9['Ticker'] = 'MJ'
df10['Ticker'] = 'MRMD'
df11['Ticker'] = 'NBEV'
df12['Ticker'] = 'TGOD'
df13['Ticker'] = 'TGODF'
df14['Ticker'] = 'TLRY'
df15['Ticker'] = 'TRST'
df16['Ticker'] = 'TRTC'
df17['Ticker'] = 'ACRGF'
df18['Ticker'] = 'ALEAF'
df19['Ticker'] = 'CURLF'
df20['Ticker'] = 'YCBD'
df21['Ticker'] = 'CRON'
df22['Ticker'] = 'GWPH'
df23['Ticker'] = 'CGC'
df24['Ticker'] = 'SMG'
df25['Ticker'] = 'TAP'
df26['Ticker'] = 'WEED.TO'
df27['Ticker'] = 'MMNFF'
df28['Ticker'] = 'MO'
df29['Ticker'] = 'BUD'
df30['Ticker'] = 'HRVSF'
df31['Ticker'] = 'TLLTF'
df32['Ticker'] = 'AYRSF'
df33['Ticker'] = 'GRWG'
df34['Ticker'] = 'PLNHF'
df35['Ticker'] = 'CXXIF'
df36['Ticker'] = 'KSHB'

# %%
merged_df= df1.append(df2) 
merged_df = merged_df.append(df3) 
merged_df = merged_df.append(df4) 
merged_df = merged_df.append(df5) 
merged_df = merged_df.append(df5) 
merged_df = merged_df.append(df6) 
merged_df = merged_df.append(df7) 
merged_df = merged_df.append(df8) 
merged_df = merged_df.append(df9)
merged_df = merged_df.append(df10)
merged_df = merged_df.append(df11)
merged_df = merged_df.append(df12)
merged_df = merged_df.append(df13)
merged_df = merged_df.append(df14)
merged_df = merged_df.append(df15)
merged_df = merged_df.append(df16)
merged_df = merged_df.append(df17)
merged_df = merged_df.append(df18)
merged_df = merged_df.append(df19)
merged_df = merged_df.append(df20)
merged_df = merged_df.append(df21)
merged_df = merged_df.append(df22)
merged_df = merged_df.append(df23)
merged_df = merged_df.append(df24)
merged_df = merged_df.append(df25)
merged_df = merged_df.append(df26)
merged_df = merged_df.append(df27)
merged_df = merged_df.append(df28)
merged_df = merged_df.append(df29)
merged_df = merged_df.append(df30)
merged_df = merged_df.append(df31)
merged_df = merged_df.append(df32)
merged_df = merged_df.append(df33)
merged_df = merged_df.append(df34)
merged_df = merged_df.append(df35)
merged_df = merged_df.append(df36)

# %%
merged_df
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume Ticker
# 0    7/1/2017  2.600  2.650  1.560  2.558      2.558    689500   ACAN
# 1    8/1/2017  1.600  2.230  1.110  1.726      1.726   1767000   ACAN
# 2    9/1/2017  1.730  2.430  1.250  1.900      1.900   1172800   ACAN
# 3   10/1/2017  1.925  2.050  1.700  1.770      1.770    513500   ACAN
# 4   11/1/2017  1.770  2.470  1.560  2.030      2.030   1047400   ACAN
# ..        ...    ...    ...    ...    ...        ...       ...    ...
# 25   4/1/2020  0.650  0.758  0.545  0.692      0.692  13585100   KSHB
# 26   5/1/2020  0.686  1.280  0.590  1.185      1.185  16761900   KSHB
# 27   6/1/2020  1.140  1.230  0.685  0.704      0.704  13913400   KSHB
# 28   7/1/2020  0.739  0.800  0.700  0.740      0.740   1403800   KSHB
# 29   7/7/2020  0.760  0.795  0.730  0.745      0.745    553009   KSHB
#
# [1227 rows x 8 columns]

# %%
df.pivot(index='foo', columns='bar', values='baz')
