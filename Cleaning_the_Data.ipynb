# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Top_Stocks = pd.read_csv('C:/Users/User/Project 3/Clean_Data_Top10_Stocks.csv')
Top_Stocks
# Out:
#      EPS-Annual Basis Ticker  Quarter-Year      CFPS   PE_Ratio    Market_Cap  \
# 0                5.76     MO          2006  1.154364  62.415441  185187000000
# 1                5.76     MO          2006  1.895984  59.386649  173528000000
# 2                5.76     MO          2006  3.683253  62.223329  171052000000
# 3                5.15     MO          2005  1.380747  53.986975  157156000000
# 4                4.36     MO          2007  0.992286  72.963354  156579000000
# ..                ...    ...           ...       ...        ...           ...
# 293             -8.50   GWPH          2017  0.000134  -5.780000   35046178480
# 294             -8.50   GWPH          2016 -1.234500  -3.700000   33054577648
# 295             -8.50   GWPH          2015 -3.465000  -9.500000   32105617568
# 296             -8.50   GWPH          2014  0.234857  -4.560000   32056173456
# 297             -8.50   GWPH          2013 -2.484800  -7.780000   32024568736
#
# ...

# %%
Top_Stocks['Ticker'].unique()
# Out:
# array(['MO', 'NBEV', 'GWPH', 'YCBD', 'TAP', 'AMRS', 'TLRY', 'SMG', 'CGC',
#        'CRBP'], dtype=object)

# %%
Top_Stocks['EPS-Annual Basis'].plot()

# %%
Top_Stocks['CFPS'].plot()

# %%
Top_Stocks.loc[Top_Stocks['CFPS']<-100]
# Out:
#      EPS-Annual Basis Ticker  Quarter-Year           CFPS    PE_Ratio  \
# 269         -0.024272   GWPH          2019    -191.086006   -1.250694
# 288         -1.162883   NBEV          2019    -130.377408   -0.025301
# 290          1.880116     MO          2010 -858313.253000  110.000000
#
#      Market_Cap       ROE  Price_Sales_Ratio  Payout_Ratio  Debt_Equity_Ratio  \
# 269    62614732 -0.078258           1.595402      0.000000           0.171679
# 288      295542 -0.074024           0.004454      0.000000           1.102034
# 290       45982  0.230480           0.073300      0.699616           6.795842
#
#      Quarter  Final_Rating
# 269        1             0
# 288        2             0
# 290        2             1

# %%
Top_Stocks = Top_Stocks.loc[(Top_Stocks['CFPS']>-100) & (Top_Stocks['CFPS']<200)]

# %%
Top_Stocks['CFPS'].plot()

# %%
Top_Stocks['PE_Ratio'].plot()

# %%
#Top_Stocks = Top_Stocks.loc[(Top_Stocks['PE_Ratio']<20000) & (Top_Stocks['PE_Ratio']>-200)]

# %%
#MO has a strong Market Cap in comparison with the other Stocks.
Top_Stocks['Market_Cap'].plot()

# %%
#We decided to keep the outlier.
#Top_Stocks = Top_Stocks.loc[(Top_Stocks['Market_Cap']<185187000000)]

# %%
Top_Stocks['ROE'].plot()

# %%
Top_Stocks = Top_Stocks.loc[(Top_Stocks['ROE']<2000)  & (Top_Stocks['ROE']>-1000)]

# %%
Top_Stocks['ROE'].plot()

# %%
Top_Stocks['Price_Sales_Ratio'].plot()

# %%
Top_Stocks = Top_Stocks.loc[(Top_Stocks['Price_Sales_Ratio']<2000)  & (Top_Stocks['Price_Sales_Ratio']>0)]

# %%
Top_Stocks['Price_Sales_Ratio'].plot()

# %%
Top_Stocks['Payout_Ratio'].plot()

# %%
#We considered to remove this column. it will not add
#value to the model due to the huge number of 0 values. 
Top_Stocks['Payout_Ratio']==0
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 293    True
# 294    True
# 295    True
# 296    True
# 297    True
# Name: Payout_Ratio, Length: 282, dtype: bool

# %%
del Top_Stocks['Payout_Ratio']

# %%
Top_Stocks['Debt_Equity_Ratio'].plot()

# %%
Top_Stocks = Top_Stocks.loc[(Top_Stocks['Debt_Equity_Ratio']<175)]

# %%
Top_Stocks['Debt_Equity_Ratio'].plot()

# %%
Top_Stocks.describe()
# Out:
#        EPS-Annual Basis  Quarter-Year        CFPS    PE_Ratio    Market_Cap  \
# count        281.000000    281.000000  281.000000  281.000000  2.810000e+02
# mean           1.174916   2013.245552    0.309491   13.868988  2.840577e+10
# std            3.797936      4.823328    3.593536   71.275229  4.434295e+10
# min           -8.500000   2002.000000  -15.636364 -199.751741  5.359292e+06
# 25%           -0.646145   2010.000000   -0.517042   -8.770711  2.148654e+09
# 50%            1.940097   2014.000000   -0.008448   21.174599  5.664650e+09
# 75%            3.675084   2017.000000    1.404548   58.321429  3.504288e+10
# max            9.320283   2020.000000   14.393939  185.674737  1.851870e+11
#
#               ROE  Price_Sales_Ratio  Debt_Equity_Ratio     Quarter  \
# count  281.000000         281.000000         281.000000  281.000000
# mean   -28.339206          67.075171           2.258211    2.544484
# std    110.006106         146.637282           2.934113    1.111135
# ...

# %%
Top_Stocks.to_csv('C:/Users/User/Project 3/Final_Table_No_Outliers.csv')
